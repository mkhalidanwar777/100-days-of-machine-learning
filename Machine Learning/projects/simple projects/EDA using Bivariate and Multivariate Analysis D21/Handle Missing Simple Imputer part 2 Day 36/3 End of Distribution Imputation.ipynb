# %% [markdown]
# ### it is juct like Arbitrary value Imputation only change a formule which we enter a value in missing place
# ### formula Depend on Graph
# ## if Graph is normal skew
# ### i.mean+3 sigma symbol
# ### ii.mean -3 sigma symbol
# ## if Graph is not normal (right or lift Skew)
# ### i. Q1-1.5IQR
# ### ii. Q3+1.5IQR
